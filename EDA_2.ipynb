# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %% [markdown]
# Ans. 11 columns and 10683 rows the data set has

# %% [markdown]
# Q2.What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %% [markdown]
# Ans. plt.figure(figsize=(8, 6))
# sns.histplot(df['Price'], bins=30, kde=True)
# plt.title('Distribution of Flight Prices')
# plt.xlabel('Flight Price')
# plt.ylabel('Frequency')
# plt.show()

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %% [markdown]
# min_price = df['Price'].min()
# max_price = df['Price'].max()
# price_range = max_price - min_price
#
# print(f"Minimum Price: {min_price}")
# print(f"Maximum Price: {max_price}")
# print(f"Range of Prices: {price_range}")

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %% [markdown]
# Ans. To create a boxplot comparing the prices of flights from different airlines, you’ll need a dataset that contains flight prices along with their corresponding airline names. If you have such a dataset, please share it, and I can help you create the boxplot. If not, I can guide you on how to do it using a hypothetical dataset or a popular dataset available online. Let me know how you’d like to proceed!
